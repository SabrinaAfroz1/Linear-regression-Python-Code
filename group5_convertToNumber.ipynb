# %%
import pandas as pd
import numpy as np
import statistics as state
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("hepatitisNull.csv")
df.head(157)
# Out:
#      age     sex  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 0     30    male    False       False    False    False     False      False
# 1     50  female    False       False     True    False     False      False
# 2     78  female     True       False     True    False     False       True
# 3     31  female     True        True    False    False     False       True
# 4     34  female     True       False    False    False     False       True
# ..   ...     ...      ...         ...      ...      ...       ...        ...
# 150   46  female     True       False     True     True      True       True
# 151   44  female     True       False     True    False     False       True
# 152   61  female    False       False     True     True     False      False
# 153   53    male    False       False     True    False     False       True
# 154   43  female     True       False     True    False     False       True
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['class'])
df['class'] = enc.transform(df['class'])

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['steroid'])
df['steroid'] = enc.transform(df['steroid'])

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['sex'])
df['sex'] = enc.transform(df['sex'])

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['antivirals'])
df['antivirals'] = enc.transform(df['antivirals'])

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['fatigue'])
df['fatigue'] = enc.transform(df['fatigue'])

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['malaise'])
df['malaise'] = enc.transform(df['malaise'])

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['anorexia'])
df['anorexia'] = enc.transform(df['anorexia'])

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['liver_big'])
df['liver_big'] = enc.transform(df['liver_big'])

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['liver_firm'])
df['liver_firm'] = enc.transform(df['liver_firm'])

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['spleen_palpable'])
df['spleen_palpable'] = enc.transform(df['spleen_palpable'])

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['spiders'])
df['spiders'] = enc.transform(df['spiders'])

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['spiders'])
df['spiders'] = enc.transform(df['spiders'])

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['ascites'])
df['ascites'] = enc.transform(df['ascites'])

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['varices'])
df['varices'] = enc.transform(df['varices'])

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['histology'])
df['histology'] = enc.transform(df['histology'])

# %%
df.to_csv(r'C:\Users\HP\Desktop\convertnumber.csv', index = False)
